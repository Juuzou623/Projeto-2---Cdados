# %% [markdown]
# # Introdução

# %% [markdown]
# ### Tema:
#
# Consumo de alcool por estudantes.
#
# ### Pergunta:
#
# Dependendo da situação escolar durante toda sua vida, ou seja, as caracteristicas academicas do aluno e de sua familia, suas condições socioêconomicas e seus resultados ao longo do ano escolar, qual será a nota final desse aluno?
#
# ### Objetivo:
#
# Prever uma informação numérica (nesse caso, o target é quantitativo), ao considerar outros 8 tipos de dados quantitativos.
#
# ### Técnica Utilizada:
#
# Uma das técnicas escolhidas pelo grupo para realizar a apalise foi a 'Regressão linear'. Dentro os motivos pelos quais escolhemos esta, encontra-se o fator de os dados a serem analizados pelo grupo são quantitativos, assim limitando as possibilidades de técnicas.
# A outra técnica escolhida pelo grupo é a 'Regression Tree', escolhida com nenhum grande motivo em mente.
#
# ### Base de Dados:
#
# #### Índice do Dataset
#
# 1.School - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# 2.Sex - student's sex (binary: 'F' - female or 'M' - male)
#
# 3.Age - student's age (numeric: from 15 to 22)
#
# 4.Address - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# 5.Famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# 6.Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# 7.Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8.Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9.Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# 10.Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# 11.Reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# 12.Guardian - student's guardian (nominal: 'mother', 'father' or 'other')
#
# 13.Traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14.Studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15.Failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16.Schoolsup - extra educational support (binary: yes or no)
#
# 17.Famsup - family educational support (binary: yes or no)
#
# 18.Paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19.Activities - extra-curricular activities (binary: yes or no)
#
# 20.Nursery - attended nursery school (binary: yes or no)
#
# 21.Higher - wants to take higher education (binary: yes or no)
#
# 22.Internet - Internet access at home (binary: yes or no)
#
# 23.Romantic - with a romantic relationship (binary: yes or no)
#
# 24.Famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25.Freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26.Goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27-Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28-Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29.Health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30.Absences - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
#     *G1 - first period grade (numeric: from 0 to 20)
#     *G2 - second period grade (numeric: from 0 to 20)
#     *G3 - final grade (numeric: from 0 to 20, output target)
#
# ### Trabalhos Acadêmicos:
#
# Alguns estudos já realizdos sobre esse tema para que possamos comparar ao final do trabalho:
#     * https://web.a.ebscohost.com/abstract?direct=true&profile=ehost&scope=site&authtype=crawler&jrnl=00220892&AN=6271257&h=zZRbm5t29cbd1F0W3Bb%2bbHAKUHq6IZXFZMcUIYW9Qj%2fW5dqzwCGNR3DzGlFQMue4V5UiPXwMUCHO4cSb55xsXQ%3d%3d&crl=c&resultNs=AdminWebAuth&resultLocal=ErrCrlNotAuth&crlhashurl=login.aspx%3fdirect%3dtrue%26profile%3dehost%26scope%3dsite%26authtype%3dcrawler%26jrnl%3d00220892%26AN%3d6271257
#     *https://muse.jhu.edu/article/201906
#     *https://www.sciencedirect.com/science/article/pii/S0022440598000089
#     *https://journals.sagepub.com/doi/abs/10.3102/0002831219833917

# %% [markdown]
# ### Bibliotecas utilizadas

# %%
import pandas as pd
import numpy as np
from scipy import stats
import csv
import matplotlib.pyplot as plt

# %% [markdown]
# # Minerando Dados e Características do Dataset

# %%
student_mat_data = pd.read_csv('student-mat.csv')

student_por_data = pd.read_csv('student-por.csv')

base = pd.concat([student_por_data,student_mat_data],ignore_index=True)

base
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   M   20       U     LE3       A     2     2  services  services
# 1040     MS   M   17       U     LE3       T     3     1  services  services
# 1041     MS   M   21       R     GT3       T     1     1     other     other
# 1042     MS   M   18       R     LE3       T     3     2  services     other
# 1043     MS   M   19       U     LE3       T     1     1     other   at_home
#
#       ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0     ...      4        3      4     1     1      3        4   0  11  11
# 1     ...      5        3      3     1     1      3        2   9  11  11
# 2     ...      4        3      2     2     3      3        6  12  13  12
# 3     ...      3        2      2     1     1      5        0  14  14  14
# 4     ...      4        3      2     1     2      5        0  11  13  13
# ...   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 1039  ...      5        5      4     4     5      4       11   9   9   9
# 1040  ...      2        4      5     3     4      2        3  14  16  16
# 1041  ...      5        5      3     3     3      3        3  10   8   7
# 1042  ...      4        4      1     3     4      5        0  11  12  10
# 1043  ...      3        2      3     3     3      5        5   8   9   9
#
# [1044 rows x 33 columns]

# %% [markdown]
# ### Índice do Dataset

# %% [markdown]
# #### Aqui escolhemos renomear a coluna G3 por um nome mais intuitivo com todo tema do dataset.

# %%
#base.rename(columns={'sex':'Genero'}, inplace=True)
#base.rename(columns={'age':'Idade'}, inplace=True)
#base.rename(columns={'health':'Saúde'}, inplace=True)
#base.rename(columns={'failures':'Reprovações'}, inplace=True)
#base.rename(columns={'famrel':'Rel. familiar'}, inplace=True)
#base.rename(columns={'Walc':'Cons_fim'}, inplace=True)
#base.rename(columns={'G3':'Nota Final'}, inplace=True)
#base.rename(columns={'absences':'Faltas'}, inplace=True)
base
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   M   20       U     LE3       A     2     2  services  services
# 1040     MS   M   17       U     LE3       T     3     1  services  services
# 1041     MS   M   21       R     GT3       T     1     1     other     other
# 1042     MS   M   18       R     LE3       T     3     2  services     other
# 1043     MS   M   19       U     LE3       T     1     1     other   at_home
#
#       ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0     ...      4        3      4     1     1      3        4   0  11  11
# 1     ...      5        3      3     1     1      3        2   9  11  11
# 2     ...      4        3      2     2     3      3        6  12  13  12
# 3     ...      3        2      2     1     1      5        0  14  14  14
# 4     ...      4        3      2     1     2      5        0  11  13  13
# ...   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 1039  ...      5        5      4     4     5      4       11   9   9   9
# 1040  ...      2        4      5     3     4      2        3  14  16  16
# 1041  ...      5        5      3     3     3      3        3  10   8   7
# 1042  ...      4        4      1     3     4      5        0  11  12  10
# 1043  ...      3        2      3     3     3      5        5   8   9   9
#
# [1044 rows x 33 columns]

# %% [markdown]
# #### Neste passo, estamos veficando se existe algum valor nulo, para assim garantir que não haja nenhuma alteração nos valores finais. Como resultado, descobrimos que não havia nenhuma linha nula, assim não tivemos que retirar nada do dataset.

# %%
base.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# #### Aqui foi feito a definição de quais são as colunas categoricas.

# %%
falsas_numericas = ['','Saúde','studytime','Medu','Fedu','Rel. familiar', 'goout', 'freetime','Genero']
categoricas = base.select_dtypes(exclude=[np.number]).columns

for column in categoricas:
    base[column] = base[column].astype('category')
    
num_base = base.select_dtypes(include=[np.number]).columns
cat_base = base.select_dtypes(exclude=[np.number]).columns
print(num_base)
print("\n {}".format(cat_base))
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')
#
#  Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
falsas_numericas = ['Medu', 'Fedu','famrel','freetime', 'goout','Walc', 'Dalc','health']
for column in falsas_numericas:
    base[column] = base[column].astype('category')
    
num_base = base.select_dtypes(include=[np.number]).columns
cat_base = base.select_dtypes(exclude=[np.number]).columns

print(num_base)
print("\n {}".format(cat_base))
# Out:
# Index(['age', 'traveltime', 'studytime', 'failures', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')
#
#  Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'schoolsup', 'famsup', 'paid',
#        'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health'],
#       dtype='object')

# %%
base.describe()
# Out:
#                age   traveltime    studytime     failures     absences  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     1.522989     1.970307     0.264368     4.434866
# std       1.239975     0.731727     0.834353     0.656142     6.210017
# min      15.000000     1.000000     1.000000     0.000000     0.000000
# 25%      16.000000     1.000000     1.000000     0.000000     0.000000
# 50%      17.000000     1.000000     2.000000     0.000000     2.000000
# 75%      18.000000     2.000000     2.000000     0.000000     6.000000
# max      22.000000     4.000000     4.000000     3.000000    75.000000
#
#                 G1           G2           G3
# count  1044.000000  1044.000000  1044.000000
# mean     11.213602    11.246169    11.341954
# std       2.983394     3.285071     3.864796
# min       0.000000     0.000000     0.000000
# 25%       9.000000     9.000000    10.000000
# 50%      11.000000    11.000000    11.000000
# 75%      13.000000    13.000000    14.000000
# max      19.000000    19.000000    20.000000

# %%
import seaborn as sns
sns.pairplot(base, height=2);

# %% [markdown]
# # Modelos de Predição

# %% [markdown]
# ## Regressão Linear

# %%
X = base[['age', 'failures', 'absences', 'G1', 'G2','traveltime','studytime']]
Y = base['G3']

# %%
import statsmodels.api as sm

def regress(Y,X):
    '''
    Y: coluna do DataFrame utilizada como variável resposta (TARGET)
    X: coluna(s) do DataFrame utilizadas como variável(is) explicativas (FEATURES)
    '''
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    
    return results

results = regress(Y,X)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     756.0
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:06   Log-Likelihood:                -1947.7
# No. Observations:                1044   AIC:                             3911.
# Df Residuals:                    1036   BIC:                             3951.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5194      0.726     -0.716      0.474      -1.944       0.905
# age           -0.0349      0.041     -0.845      0.398      -0.116       0.046
# failures      -0.2517      0.084     -3.012      0.003      -0.416      -0.088
# absences       0.0264      0.008      3.312      0.001       0.011       0.042
# G1             0.1278      0.032      3.977      0.000       0.065       0.191
# G2             0.9626      0.029     33.041      0.000       0.905       1.020
# traveltime     0.1500      0.067      2.229      0.026       0.018       0.282
# studytime     -0.0470      0.060     -0.783      0.434      -0.165       0.071
# ==============================================================================
# Omnibus:                      674.212   Durbin-Watson:                   1.795
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8627.436
# Skew:                          -2.809   Prob(JB):                         0.00
# Kurtosis:                      15.914   Cond. No.                         357.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = base[['age','failures', 'absences', 'G1', 'G2','traveltime']]
Y = base['G3']

# %%
results = regress(Y,X)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     882.2
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:06   Log-Likelihood:                -1948.0
# No. Observations:                1044   AIC:                             3910.
# Df Residuals:                    1037   BIC:                             3945.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.5678      0.723     -0.785      0.432      -1.987       0.851
# age           -0.0365      0.041     -0.886      0.376      -0.117       0.044
# failures      -0.2461      0.083     -2.957      0.003      -0.409      -0.083
# absences       0.0268      0.008      3.367      0.001       0.011       0.042
# G1             0.1253      0.032      3.919      0.000       0.063       0.188
# G2             0.9629      0.029     33.058      0.000       0.906       1.020
# traveltime     0.1531      0.067      2.279      0.023       0.021       0.285
# ==============================================================================
# Omnibus:                      676.992   Durbin-Watson:                   1.791
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8765.107
# Skew:                          -2.821   Prob(JB):                         0.00
# Kurtosis:                      16.026   Cond. No.                         354.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = base[['failures', 'absences', 'G1', 'G2','traveltime']]
Y = base['G3']

# %%
results = regress(Y,X)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.836
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     1059.
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:06   Log-Likelihood:                -1948.4
# No. Observations:                1044   AIC:                             3909.
# Df Residuals:                    1038   BIC:                             3938.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.1683      0.251     -4.654      0.000      -1.661      -0.676
# failures      -0.2644      0.081     -3.278      0.001      -0.423      -0.106
# absences       0.0258      0.008      3.279      0.001       0.010       0.041
# G1             0.1256      0.032      3.931      0.000       0.063       0.188
# G2             0.9626      0.029     33.055      0.000       0.906       1.020
# traveltime     0.1514      0.067      2.254      0.024       0.020       0.283
# ==============================================================================
# Omnibus:                      682.516   Durbin-Watson:                   1.790
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8983.573
# Skew:                          -2.846   Prob(JB):                         0.00
# Kurtosis:                      16.195   Cond. No.                         90.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, probplot

probplot(results.resid, dist="norm", plot= plt);

# %%
plt.boxplot(results.resid);

# %%
print(np.where(results.resid<-6))
print(np.where(results.resid>3))
# Out:
# (array([163, 172, 519, 586, 637, 639, 640, 789, 817, 888, 908, 913, 945,
#        959, 965, 982, 983, 986, 990, 992], dtype=int64),)
# (array([ 61, 307, 389, 518, 692], dtype=int64),)

# %%
base = base.drop(axis=0, index=[ 163, 172, 519, 586, 637, 639, 640, 789, 817, 888, 908, 913, 945,
       959, 965, 982, 983, 986, 990, 992, 61, 307, 389, 518, 692])

# %%
base
# Out:
#      school sex  age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A    4    4   at_home   teacher
# 1        GP   F   17       U     GT3       T    1    1   at_home     other
# 2        GP   F   15       U     LE3       T    1    1   at_home     other
# 3        GP   F   15       U     GT3       T    4    2    health  services
# 4        GP   F   16       U     GT3       T    3    3     other     other
# ...     ...  ..  ...     ...     ...     ...  ...  ...       ...       ...
# 1039     MS   M   20       U     LE3       A    2    2  services  services
# 1040     MS   M   17       U     LE3       T    3    1  services  services
# 1041     MS   M   21       R     GT3       T    1    1     other     other
# 1042     MS   M   18       R     LE3       T    3    2  services     other
# 1043     MS   M   19       U     LE3       T    1    1     other   at_home
#
#       ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0     ...      4        3      4     1     1      3        4   0  11  11
# 1     ...      5        3      3     1     1      3        2   9  11  11
# 2     ...      4        3      2     2     3      3        6  12  13  12
# 3     ...      3        2      2     1     1      5        0  14  14  14
# 4     ...      4        3      2     1     2      5        0  11  13  13
# ...   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 1039  ...      5        5      4     4     5      4       11   9   9   9
# 1040  ...      2        4      5     3     4      2        3  14  16  16
# 1041  ...      5        5      3     3     3      3        3  10   8   7
# 1042  ...      4        4      1     3     4      5        0  11  12  10
# 1043  ...      3        2      3     3     3      5        5   8   9   9
#
# [1019 rows x 33 columns]

# %%
X = base[['failures', 'absences', 'G1', 'G2','traveltime']]
Y = base['G3']

# %%
results = regress(Y,X)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     2103.
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:07   Log-Likelihood:                -1501.6
# No. Observations:                1019   AIC:                             3015.
# Df Residuals:                    1013   BIC:                             3045.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2112      0.174     -1.217      0.224      -0.552       0.129
# failures      -0.2573      0.055     -4.672      0.000      -0.365      -0.149
# absences       0.0060      0.005      1.122      0.262      -0.005       0.017
# G1             0.0801      0.022      3.677      0.000       0.037       0.123
# G2             0.9551      0.020     48.279      0.000       0.916       0.994
# traveltime     0.0653      0.046      1.422      0.155      -0.025       0.155
# ==============================================================================
# Omnibus:                      416.185   Durbin-Watson:                   1.742
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3470.801
# Skew:                          -1.652   Prob(JB):                         0.00
# Kurtosis:                      11.416   Cond. No.                         91.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = base[['failures', 'G1', 'G2','traveltime']]
Y = base['G3']

# %%
results = regress(Y,X)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     2628.
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:07   Log-Likelihood:                -1502.3
# No. Observations:                1019   AIC:                             3015.
# Df Residuals:                    1014   BIC:                             3039.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1691      0.169     -0.998      0.319      -0.502       0.163
# failures      -0.2531      0.055     -4.606      0.000      -0.361      -0.145
# G1             0.0793      0.022      3.644      0.000       0.037       0.122
# G2             0.9547      0.020     48.261      0.000       0.916       0.994
# traveltime     0.0631      0.046      1.375      0.169      -0.027       0.153
# ==============================================================================
# Omnibus:                      425.084   Durbin-Watson:                   1.741
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3654.482
# Skew:                          -1.686   Prob(JB):                         0.00
# Kurtosis:                      11.643   Cond. No.                         86.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = base[['failures', 'G1', 'G2']]
Y = base['G3']
results = regress(Y,X)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     3501.
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:08   Log-Likelihood:                -1503.2
# No. Observations:                1019   AIC:                             3014.
# Df Residuals:                    1015   BIC:                             3034.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0535      0.147     -0.364      0.716      -0.342       0.235
# failures      -0.2499      0.055     -4.549      0.000      -0.358      -0.142
# G1             0.0795      0.022      3.648      0.000       0.037       0.122
# G2             0.9528      0.020     48.262      0.000       0.914       0.992
# ==============================================================================
# Omnibus:                      423.669   Durbin-Watson:                   1.740
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3640.902
# Skew:                          -1.679   Prob(JB):                         0.00
# Kurtosis:                      11.630   Cond. No.                         74.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
probplot(results.resid, dist="norm", plot= plt);

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, random_state= 100)
X_train_mod1 = X_train

# %% [markdown]
# MODELO 1

# %%
results = regress(y_train,X_train)
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     G3   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     3173.
# Date:                Tue, 30 Nov 2021   Prob (F-statistic):               0.00
# Time:                        19:06:09   Log-Likelihood:                -1370.2
# No. Observations:                 917   AIC:                             2748.
# Df Residuals:                     913   BIC:                             2768.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0761      0.157     -0.483      0.629      -0.385       0.233
# failures      -0.2621      0.058     -4.533      0.000      -0.376      -0.149
# G1             0.0740      0.023      3.173      0.002       0.028       0.120
# G2             0.9591      0.021     46.091      0.000       0.918       1.000
# ==============================================================================
# Omnibus:                      383.260   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3204.290
# Skew:                          -1.688   Prob(JB):                         0.00
# Kurtosis:                      11.513   Cond. No.                         74.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 7.47683077, 12.24786081, 12.24786081, 10.18152737,  8.26323344,
#        11.28871384, 14.53625351,  9.9594681 , 10.25554712, 11.28871384,
#        12.24786081, 10.18152737, 14.46223376, 10.95255986, 14.46223376,
#        13.35504728,  9.29640016, 17.4136944 , 11.28871384,  9.07434089,
#         8.88622643, 13.28102753,  9.14836065, 11.3627336 ,  8.3372532 ,
#        14.46223376, 13.35504728, 13.35504728, 14.46223376,  7.15604697,
#        12.28180561, 14.31419424,  6.89391274, 17.63575367, 13.35504728,
#        11.57555285,  9.37041992, 12.32188056, 17.26565489,  5.16373329,
#        12.24786081,  9.37041992, 12.32188056, 12.32188056, 15.34736096,
#        12.39590032, 12.54393983, 10.32956688,  7.23006672,  9.14836065,
#         8.88622643, 13.35504728, 13.5030868 , 13.28102753, 16.45454744,
#        11.3627336 ,  7.51690573, 10.18152737, 14.388214  , 14.46223376,
#        11.28871384, 11.28871384, 10.25554712, 10.18152737, 12.09982129,
#        11.21469409,  6.04886049, 11.21469409,  7.92707946,  6.1969    ,
#        10.95255986, 14.31419424, 18.52088088, 10.40358664, 12.39590032,
#         9.84537339, 17.19163513, 11.28871384, 15.49540048, 15.42138072,
#         9.29640016, 11.3627336 , 14.31419424, 13.28102753, 13.35504728,
#        14.388214  , 12.39590032, 13.28102753, 11.3627336 , 13.35504728,
#         9.22238041, 12.32188056, 13.20700777, 13.42906704,  8.04117417,
#        13.42906704, 14.53625351, 12.46992008,  9.22238041, 12.02580154,
#        15.34736096,  9.1082857 ])

# %%
df_Linear = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
df_Linear.head()
# Out:
#      Real Values  Predicted Values
# 806           10          7.476831
# 48            13         12.247861
# 363           14         12.247861
# 539           10         10.181527
# 150            9          8.263233

# %%
from sklearn.metrics import r2_score
Rsqrt_Linear = r2_score(y_test, y_pred)
Rsqrt_Linear
# Out:
# 0.8991519710675223

# %% [markdown]
# ## MODELO 2
#
# Como segundo modelo escolhemos usar a "Regression Tree", que é construída por meio de um processo chamado como particionamento recursivo binário, que é um processo iterativo que divide os dados em partições ou ramificações e, em seguida, continua dividindo cada partição em grupos menores conforme o método sobe em cada ramificação.
#
# Inicialmente, todos os registros no Conjunto de treinamento são agrupados na mesma partição. O algoritmo então começa a alocar os dados nas duas primeiras partições ou ramificações, usando todas as divisões binárias possíveis em cada campo. Então ele seleciona a divisão que minimiza a soma dos desvios quadrados da média nas duas partições separadas. Essa regra de divisão é então aplicada a cada um dos novos ramos. Esse processo continua até que cada nó alcance um tamanho de nó mínimo especificado pelo usuário e se torne um nó terminal. (Se a soma dos desvios quadrados da média em um nó for zero, esse nó será considerado um nó terminal, mesmo que não tenha atingido o tamanho mínimo.)

# %%
X = base[[ 'G1', 'G2','failures']]
Y = base['G3']

# %% [markdown]
# Separando a base de dados em 2 bases diferentes, uma de teste e outra de treinamento

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.1, random_state= 100)

# %%
X_train
# Out:
#       G1  G2  failures
# 1026   8   9         0
# 147   13  14         0
# 861   12  13         0
# 166   11   9         0
# 485   11  10         0
# ...   ..  ..       ...
# 869    6   6         0
# 885   14  13         0
# 849   16  16         0
# 805   16  12         0
# 527   10   9         0
#
# [917 rows x 3 columns]

# %%
y_train
# Out:
# 1026    10
# 147     14
# 861     14
# 166     11
# 485     11
#         ..
# 869      6
# 885     13
# 849     16
# 805     13
# 527     10
# Name: G3, Length: 917, dtype: int64

# %% [markdown]
# Importando todas as bibliotecas extras que iremos precisar.

# %%
from numpy import reshape
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([10.        , 12.31034483, 12.31034483, 10.05882353,  8.66666667,
#        11.15151515, 15.        , 10.        , 10.24137931, 11.15151515,
#        12.31034483, 10.05882353, 15.09090909, 10.66666667, 15.09090909,
#        13.        ,  9.875     , 17.42857143, 11.15151515,  8.83333333,
#         9.        , 13.20689655,  9.46153846, 11.38888889,  9.14285714,
#        15.09090909, 13.        , 13.        , 15.09090909,  7.        ,
#        13.        , 14.13043478,  7.        , 18.        , 13.        ,
#        12.        , 10.        , 12.54545455, 16.33333333,  5.66666667,
#        12.31034483, 10.        , 12.54545455, 12.54545455, 15.52380952,
#        12.56521739, 13.        , 10.45      ,  7.4       ,  9.46153846,
#         9.        , 13.        , 14.        , 13.20689655, 16.23076923,
#        11.38888889,  6.5       , 10.05882353, 14.5       , 15.09090909,
#        11.15151515, 11.15151515, 10.24137931, 10.05882353, 13.        ,
#        11.22222222,  6.        , 11.22222222,  8.5       ,  5.33333333,
#        10.66666667, 14.13043478, 18.        , 11.125     , 12.56521739,
#        10.        , 16.33333333, 11.15151515, 15.53846154, 15.26315789,
#         9.875     , 11.38888889, 14.13043478, 13.20689655, 13.        ,
#        14.5       , 12.56521739, 13.20689655, 11.38888889, 13.        ,
#         9.5       , 12.54545455, 13.375     , 13.25      ,  7.5       ,
#        13.25      , 15.        , 12.14285714,  9.5       , 13.        ,
#        15.52380952, 10.        ])

# %%
Tree = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
Tree.head()
# Out:
#      Real Values  Predicted Values
# 806           10         10.000000
# 48            13         12.310345
# 363           14         12.310345
# 539           10         10.058824
# 150            9          8.666667

# %% [markdown]
# Aqui plotamos gráficos que mostram a descrepância entre os números do dataset e os previstos. Apenas para ter um entendimento visual do estado da regressão.

# %%
plt.scatter(X_test['G1'], y_test, color = 'red')
plt.scatter(X_test['G1'], y_pred, color = 'green')
plt.title('Decision Tree Regression')
plt.xlabel('Nota G1')
plt.ylabel('Nota Final')
plt.show()

plt.scatter(X_test['G2'], y_test, color = 'red')
plt.scatter(X_test['G2'], y_pred, color = 'green')
plt.title('Decision Tree Regression')
plt.xlabel('Nota G2')
plt.ylabel('Nota Final')
plt.show()

plt.scatter(X_test['failures'], y_test, color = 'red')
plt.scatter(X_test['failures'], y_pred, color = 'green')
plt.title('Decision Tree Regression')
plt.xlabel('failures')
plt.ylabel('Nota Final')
plt.show()

# %% [markdown]
# Gráfico entre os valores do dataset e da previsão.

# %%
plt.scatter(Tree['Real Values'],Tree['Predicted Values'] , color = 'red')
plt.title('Decision Tree Regression')
plt.xlabel('Valores reais')
plt.ylabel('Previsão')
plt.show()

# %% [markdown]
# Demonstração por texto do funcionamento da primeira árvore.

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
regr = DecisionTreeRegressor(random_state=100)
regr.fit(X_train, y_train)
text_representation = tree.export_text(regr)
print(text_representation)
# Out:
# |--- feature_1 <= 11.50
# |   |--- feature_1 <= 6.50
# |   |   |--- feature_1 <= 4.50
# |   |   |   |--- value: [0.00]
# |   |   |--- feature_1 >  4.50
# |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |   |   |--- feature_0 <= 5.50
# |   |   |   |   |   |   |   |   |--- value: [5.50]
# |   |   |   |   |   |   |   |--- feature_0 >  5.50
# |   |   |   |   |   |   |   |   |--- value: [5.67]
# |   |   |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |   |   |--- value: [6.00]
# |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |   |   |--- value: [5.33]
# |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |--- value: [7.50]
# |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |--- feature_0 <= 5.50
# |   |   |   |   |   |   |--- feature_0 <= 4.00
# |   |   |   |   |   |   |   |--- value: [5.00]
# |   |   |   |   |   |   |--- feature_0 >  4.00
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |--- feature_0 >  5.50
# |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- value: [1.25]
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |--- value: [2.50]
# |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [4.00]
# |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |--- value: [5.00]
# |   |--- feature_1 >  6.50
# |   |   |--- feature_1 <= 8.50
# |   |   |   |--- feature_1 <= 7.50
# |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |--- value: [7.40]
# |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |--- value: [6.67]
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- value: [7.67]
# |   |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |   |--- value: [8.50]
# |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |--- value: [5.33]
# |   |   |   |--- feature_1 >  7.50
# |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [7.50]
# |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |--- value: [8.67]
# |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 5.50
# |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |   |--- feature_0 >  5.50
# |   |   |   |   |   |   |   |   |--- value: [6.50]
# |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |--- feature_0 <= 5.50
# |   |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |   |--- feature_0 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [8.36]
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [8.50]
# |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |--- value: [8.50]
# |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- value: [8.67]
# |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |--- value: [9.14]
# |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- value: [8.43]
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- value: [8.50]
# |   |   |   |   |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |--- feature_1 >  8.50
# |   |   |   |--- feature_1 <= 10.50
# |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |--- feature_0 <= 5.50
# |   |   |   |   |   |   |   |--- value: [7.00]
# |   |   |   |   |   |   |--- feature_0 >  5.50
# |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.83]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [8.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [9.46]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [9.50]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.33]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [9.88]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [9.67]
# |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.33]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.06]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.24]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [10.33]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [9.75]
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.50]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [10.45]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [10.50]
# |   |   |   |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [11.12]
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |--- feature_1 >  10.50
# |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.11]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.22]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [11.15]
# |   |   |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |   |   |--- value: [11.39]
# |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |--- value: [10.86]
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.67]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [10.50]
# |   |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- value: [11.67]
# |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |   |--- value: [12.50]
# |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |--- value: [9.00]
# |--- feature_1 >  11.50
# |   |--- feature_1 <= 14.50
# |   |   |--- feature_1 <= 13.50
# |   |   |   |--- feature_1 <= 12.50
# |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |--- value: [12.57]
# |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |--- value: [12.31]
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |--- value: [12.55]
# |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |--- value: [12.57]
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [12.14]
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [12.33]
# |   |   |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |--- feature_1 >  12.50
# |   |   |   |   |--- feature_0 <= 9.00
# |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |--- feature_0 >  9.00
# |   |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.38]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.21]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.25]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |   |--- feature_2 <= 1.00
# |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |--- feature_2 >  1.00
# |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |--- feature_1 >  13.50
# |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |   |   |--- value: [14.67]
# |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |--- value: [14.13]
# |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |--- value: [14.50]
# |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |--- value: [15.09]
# |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |--- value: [15.00]
# |   |--- feature_1 >  14.50
# |   |   |--- feature_1 <= 16.50
# |   |   |   |--- feature_1 <= 15.50
# |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.33]
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.52]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |   |   |--- value: [15.26]
# |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |--- value: [15.54]
# |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |--- value: [15.50]
# |   |   |   |--- feature_1 >  15.50
# |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |--- feature_0 <= 13.00
# |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |--- feature_0 >  13.00
# |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |--- value: [16.17]
# |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |--- value: [16.23]
# |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |--- value: [16.25]
# |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |--- value: [16.00]
# |   |   |--- feature_1 >  16.50
# |   |   |   |--- feature_1 <= 17.50
# |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |--- value: [16.33]
# |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |--- value: [17.00]
# |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |--- value: [17.43]
# |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |--- value: [17.38]
# |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |--- feature_1 >  17.50
# |   |   |   |   |--- feature_1 <= 18.50
# |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |--- value: [18.25]
# |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |   |--- value: [17.70]
# |   |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |--- value: [18.50]
# |   |   |   |   |--- feature_1 >  18.50
# |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |--- value: [20.00]

# %% [markdown]
# Aqui plotamos a árvore perfeita do nosso dataset, já que ela prevê quse perfeitamente nosso resultado. Porém, ela não se mostra tão útil para nossa análise, pois se mostra muito expecífica para este dataset.

# %%
plt.figure(figsize=(50,40))
colunas = ['G1', 'G2', 'Reprovações']
fig = tree.plot_tree(regr, feature_names=colunas, filled=True)
plt.savefig('Arvore.png')

# %% [markdown]
# Calculo do R quadrado. Que represena o índice de correlação entre duas variaveis, ou seja, ela mede o quanto uma variavel influencia em uma outra variavel.

# %%
from sklearn.metrics import r2_score
Rsqrt_Tree = r2_score(Tree['Predicted Values'], Tree['Real Values'])
Rsqrt_Tree
# Out:
# 0.9013655827225302

# %% [markdown]
# Demonstração por texto do funcionamento da segunda árvore.

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
regr = DecisionTreeRegressor(max_depth=5, random_state=100)
regr.fit(X_train, y_train)
text_representation = tree.export_text(regr)
print(text_representation)
# Out:
# |--- feature_1 <= 11.50
# |   |--- feature_1 <= 6.50
# |   |   |--- feature_1 <= 4.50
# |   |   |   |--- value: [0.00]
# |   |   |--- feature_1 >  4.50
# |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |--- value: [5.14]
# |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |--- value: [7.50]
# |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |--- value: [2.20]
# |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |--- value: [4.44]
# |   |--- feature_1 >  6.50
# |   |   |--- feature_1 <= 8.50
# |   |   |   |--- feature_1 <= 7.50
# |   |   |   |   |--- feature_2 <= 2.50
# |   |   |   |   |   |--- value: [7.39]
# |   |   |   |   |--- feature_2 >  2.50
# |   |   |   |   |   |--- value: [5.17]
# |   |   |   |--- feature_1 >  7.50
# |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |--- value: [7.85]
# |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |--- value: [8.62]
# |   |   |--- feature_1 >  8.50
# |   |   |   |--- feature_1 <= 10.50
# |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |--- value: [9.49]
# |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |--- value: [10.30]
# |   |   |   |--- feature_1 >  10.50
# |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |--- value: [11.16]
# |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |--- value: [9.00]
# |--- feature_1 >  11.50
# |   |--- feature_1 <= 14.50
# |   |   |--- feature_1 <= 13.50
# |   |   |   |--- feature_1 <= 12.50
# |   |   |   |   |--- feature_0 <= 11.50
# |   |   |   |   |   |--- value: [12.33]
# |   |   |   |   |--- feature_0 >  11.50
# |   |   |   |   |   |--- value: [12.52]
# |   |   |   |--- feature_1 >  12.50
# |   |   |   |   |--- feature_0 <= 9.00
# |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |--- feature_0 >  9.00
# |   |   |   |   |   |--- value: [13.18]
# |   |   |--- feature_1 >  13.50
# |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |--- value: [14.19]
# |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |--- value: [14.50]
# |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |--- value: [15.08]
# |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |--- value: [14.00]
# |   |--- feature_1 >  14.50
# |   |   |--- feature_1 <= 16.50
# |   |   |   |--- feature_1 <= 15.50
# |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |--- value: [15.43]
# |   |   |   |--- feature_1 >  15.50
# |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |--- value: [16.20]
# |   |   |--- feature_1 >  16.50
# |   |   |   |--- feature_1 <= 17.50
# |   |   |   |   |--- feature_0 <= 14.50
# |   |   |   |   |   |--- value: [16.33]
# |   |   |   |   |--- feature_0 >  14.50
# |   |   |   |   |   |--- value: [17.39]
# |   |   |   |--- feature_1 >  17.50
# |   |   |   |   |--- feature_1 <= 18.50
# |   |   |   |   |   |--- value: [17.96]
# |   |   |   |   |--- feature_1 >  18.50
# |   |   |   |   |   |--- value: [19.25]

# %% [markdown]
# Aqui plotamos uma árvore com uma profundidade menor que a anterior, o que faz com que esta possa ser usada por uma gama maior de dataset, assim não se restringindo apenas ao dataset na qual foi treinada. Porém, ao optar por isso, estamos sacrificando a precisão da árvore. Ou seja, trocamos precisão por abrangencia.

# %%
plt.figure(figsize=(50,40))
colunas = ['G1', 'G2', 'Reprovações']
fig = tree.plot_tree(regr, feature_names=colunas, filled=True)
plt.savefig('Arvore.png')

# %%
y_pred_Tree = regr.predict(X_test)

# %%
df_Tree = pd.DataFrame({'Real Values':y_test, 'Predicted Values':y_pred})
df_Tree.head()
# Out:
#      Real Values  Predicted Values
# 806           10         10.000000
# 48            13         12.310345
# 363           14         12.310345
# 539           10         10.058824
# 150            9          8.666667

# %%
from sklearn.metrics import r2_score
Rsqrt_Tree = r2_score(Tree['Predicted Values'], Tree['Real Values'])
Rsqrt_Tree
# Out:
# 0.9013655827225302

# %% [markdown]
# MODELO 3

# %%
from sklearn.ensemble import RandomForestRegressor
regressor2 = RandomForestRegressor(n_estimators = 50, random_state = 100)
regressor2.fit(X_train, y_train);

# %%
y_previsao3 = regressor.predict(X_Flor_teste)
y_previsao3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-158d17e11cb4> in <module>
# ----> 1 y_previsao3 = regressor.predict(X_Flor_teste)
#       2 y_previsao3
#
# NameError: name 'X_Flor_teste' is not defined

# %%
Florest = pd.DataFrame({'Real Values':y_Flor_teste, 'Predicted Values':y_previsao3})
Florest.head()

# %%
from sklearn.metrics import r2_score
Rsqrt_Tree2 = r2_score(Florest['Real Values'], Florest['Predicted Values'])
Rsqrt_Tree2
